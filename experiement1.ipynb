# %%
import pandas as pd

# %%
data=pd.read_csv("Airpassengers.csv")
data.head()
# Out:
#      Month #Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        141 non-null    object
#  1   #Passengers  141 non-null    object
# dtypes: object(2)
# memory usage: 2.3+ KB

# %%
data["#Passengers"].count()
# Out:
# 141

# %%
data["#passengers"]=data["#Passengers"].fillna(mean)

# %%
data["#Passengers"].count()

# %%
data["#passengers"]=data["#Passengers"].fillna(mean)

# %%
data["#Passengers"].count()

# %%
data.describe()
# Out:
#        #Passengers  #passengers
# count   144.000000   144.000000
# mean    280.298611   280.298611
# std     119.966317   119.966317
# min     104.000000   104.000000
# 25%     180.000000   180.000000
# 50%     265.500000   265.500000
# 75%     360.500000   360.500000
# max     622.000000   622.000000

# %%
data.fillna(method ='bfill')
# Out:
#        Month  #Passengers  #passengers
# 0    1949-01          112          112
# 1    1949-02          118          118
# 2    1949-03          132          132
# 3    1949-04          129          129
# 4    1949-05          121          121
# ..       ...          ...          ...
# 139  1960-08          606          606
# 140  1960-09          508          508
# 141  1960-10          461          461
# 142  1960-11          390          390
# 143  1960-12          432          432
#
# [144 rows x 3 columns]

# %%
data["#Passengers"].count()
data.head()
# Out:
#      Month  #Passengers  #passengers
# 0  1949-01          112          112
# 1  1949-02          118          118
# 2  1949-03          132          132
# 3  1949-04          129          129
# 4  1949-05          121          121

# %%
data["#Passengers"].count()
# Out:
# 144

# %%
data.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# #passengers    0
# dtype: int64

# %%
data.fillna(0)
# Out:
#        Month  #Passengers  #passengers
# 0    1949-01          112          112
# 1    1949-02          118          118
# 2    1949-03          132          132
# 3    1949-04          129          129
# 4    1949-05          121          121
# ..       ...          ...          ...
# 139  1960-08          606          606
# 140  1960-09          508          508
# 141  1960-10          461          461
# 142  1960-11          390          390
# 143  1960-12          432          432
#
# [144 rows x 3 columns]

# %%
data.fillna(0)
# Out:
#        Month  #Passengers  #passengers
# 0    1949-01          112          112
# 1    1949-02          118          118
# 2    1949-03          132          132
# 3    1949-04          129          129
# 4    1949-05          121          121
# ..       ...          ...          ...
# 139  1960-08          606          606
# 140  1960-09          508          508
# 141  1960-10          461          461
# 142  1960-11          390          390
# 143  1960-12          432          432
#
# [144 rows x 3 columns]

# %%
data['year'] = "1940"
data
# Out:
#        Month  #Passengers  #passengers     Day  year
# 0    1949-01          112          112  Monday  1940
# 1    1949-02          118          118  Monday  1940
# 2    1949-03          132          132  Monday  1940
# 3    1949-04          129          129  Monday  1940
# 4    1949-05          121          121  Monday  1940
# ..       ...          ...          ...     ...   ...
# 139  1960-08          606          606  Monday  1940
# 140  1960-09          508          508  Monday  1940
# 141  1960-10          461          461  Monday  1940
# 142  1960-11          390          390  Monday  1940
# 143  1960-12          432          432  Monday  1940
#
# [144 rows x 5 columns]

# %%
import pandas as pd

# %%
data=pd.read_csv("Airpassengers.csv")
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01        112.0
# 1  1949-02        118.0
# 2  1949-03        132.0
# 3  1949-04        129.0
# 4  1949-05        121.0

# %%
data=["#passenger"].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data=["#passenger"].count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
data.fillna(data.median(numeric_only=True))
print(data)
# Out:
#        Month  #Passengers
# 0    1949-01        112.0
# 1    1949-02        118.0
# 2    1949-03        132.0
# 3    1949-04        129.0
# 4    1949-05        121.0
# ..       ...          ...
# 139  1960-08        606.0
# 140  1960-09        508.0
# 141  1960-10        461.0
# 142  1960-11        390.0
# 143  1960-12        432.0
#
# [144 rows x 2 columns]

# %% [markdown]
# # fill null rowns with values using ffill

# %%
data.fillna(method='pad')
# Out:
#        Month  #Passengers
# 0    1949-01        112.0
# 1    1949-02        118.0
# 2    1949-03        132.0
# 3    1949-04        129.0
# 4    1949-05        121.0
# ..       ...          ...
# 139  1960-08        606.0
# 140  1960-09        508.0
# 141  1960-10        461.0
# 142  1960-11        390.0
# 143  1960-12        432.0
#
# [144 rows x 2 columns]

# %%
data.fillna(method='pad',inplace=True)

# %%
data["#Passengers"].count()
# Out:
# 144

# %%
import pandas as pd

# %%
data=pd.read_csv("Airpassengers.csv")
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01        112.0
# 1  1949-02        118.0
# 2  1949-03        132.0
# 3  1949-04        129.0
# 4  1949-05        121.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
plt.bar(df["TAX"],df["AGE"])
plt.show()

# %%
df.shape
# Out:
# (506, 14)

# %%
data=pd.read_csv("Airpassengers.csv")
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01        112.0
# 1  1949-02        118.0
# 2  1949-03        132.0
# 3  1949-04        129.0
# 4  1949-05        121.0
